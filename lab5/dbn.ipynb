# %%
import numpy as np
import matplotlib.pyplot as plt
import mkl

mkl.set_num_threads(2)
np.random.seed(1234)

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
plt.rcParams["figure.figsize"] = [16, 9]

# %% [markdown]
# ### Handy utility functions

# %%
def append_ones(matrix, axis=1):
    return np.concatenate((matrix, np.ones((matrix.shape[0], 1), dtype=np.float32)), axis=axis)

def zeros(*dims):
    return np.zeros(shape=tuple(dims), dtype=np.float32)

def ones(*dims):
    return np.ones(shape=tuple(dims), dtype=np.float32)

def rand(*dims):
    return np.random.rand(*dims).astype(np.float32)

def chunks(seq, size):
    return (seq[pos:pos + size] for pos in range(0, len(seq), size))

def tiles(examples):
    rows_count = examples.shape[0]
    cols_count = examples.shape[1]
    tile_height = examples.shape[2]
    tile_width = examples.shape[3]
    
    space_between_tiles = 2
    img_matrix = np.empty(shape=(rows_count * (tile_height + space_between_tiles) - space_between_tiles,  
                                 cols_count * (tile_width + space_between_tiles) - space_between_tiles))
    img_matrix.fill(np.nan)

    for r in range(rows_count):
        for c in range(cols_count):
            x_0 = r * (tile_height + space_between_tiles)
            y_0 = c * (tile_width + space_between_tiles)
            ex_min = np.min(examples[r, c])
            ex_max = np.max(examples[r, c])
            img_matrix[x_0:x_0 + tile_height, y_0:y_0 + tile_width] = (examples[r, c] - ex_min) / (ex_max - ex_min)
    
    plt.matshow(img_matrix, cmap='gray', interpolation='none')
    plt.axis('off')
    plt.show()

# %% [markdown]
# # MNIST dataset

# %%
import mnist
digits = np.reshape(mnist.train_images()[:12*24], newshape=(12, 24, 28, 28))
tiles(digits)

# %% [markdown]
# # Restricted Boltzmann Machine & Contrastive Divergence algorithm

# %%
def sigmoid(matrix):
    return 1.0 / (1.0 + np.exp(-matrix))

class Rbm:
    def __init__(self, visible_size, hidden_size, learning_rate, momentum):
        self.visible_size = visible_size
        self.hidden_size = hidden_size
        self.learning_rate = learning_rate
        self.momentum = momentum
        
        self.reset()
    
    def reset(self):
        self.W = np.random.normal(scale=0.01, size=(self.visible_size+1, self.hidden_size+1)).astype(np.float32)
        self.W[:, -1] = 0.0
        self.W[-1, :] = 0.0
        self.M = zeros(self.visible_size+1, self.hidden_size+1)

# %%
def reconstuction_error(rbm, minibatch):
    observations_count = minibatch.shape[0]
    visible = zeros(observations_count, rbm.visible_size)
    hidden = append_ones(zeros(observations_count, rbm.hidden_size))

    hidden[:, :-1] = sigmoid(minibatch @ rbm.W[:, :-1]) > rand(rbm.hidden_size)
    visible = sigmoid(hidden @ rbm.W[:-1, :].T)

    return np.sum((minibatch[:, :-1] - visible) ** 2) / observations_count

# %%
def train_epoch(rbm, dataset, batch_size):
    batches_limit = dataset.shape[0] / batch_size
    for batch_idx, batch in enumerate(chunks(dataset, batch_size)):
        cdk(rbm, batch)
        if batch_idx % round(batches_limit / 50) == 0: print("#", end="")

def run_training(rbm, dataset, monitoring_set, batch_size, epochs_count):
    for epoch in range(epochs_count):
        print("Epoch {}:".format(epoch),  end="\t")
        
        if epoch == 5:
            rbm.momentum = 0.8

        start_time = time.time()
        train_epoch(rbm, dataset, batch_size)
        elapsed = time.time() - start_time
        
        error = reconstuction_error(rbm, monitoring_set)
        print("\telapsed: {0:>2.2f}s, reconstruction error: {1:>2.2f}".format(elapsed, error))

    print("Training finished!")

# %%
def draw_filters(rbm):
    filters = np.reshape(np.transpose(rbm.W)[:-1, :-1], newshape=(8, -1, 28, 28))
    tiles(filters)

# %% [markdown]
# # 1. RBM Training with momentum

# %%
def cdk(rbm, minibatch, k=1):
    observations_count = minibatch.shape[0]

    positive_visible = minibatch
    negative_visible = append_ones(zeros(observations_count, rbm.visible_size))

    positive_hidden = append_ones(zeros(observations_count, rbm.hidden_size))
    negative_hidden = append_ones(zeros(observations_count, rbm.hidden_size))

    #
    positive_hidden[:, :-1] = sigmoid(positive_visible @ rbm.W[:, :-1])
    
    negative_hidden[:, :-1] = positive_hidden[:, :-1] > rand(positive_hidden.shape[0], rbm.hidden_size)
    for _ in range(k-1):
        negative_visible[:, :-1] = sigmoid(negative_hidden @ rbm.W[:-1, :].T) > rand(negative_hidden.shsape[0], rbm.visible_size) # fantazja
        negative_hidden[:, :-1] = sigmoid(negative_visible @ rbm.W[:, :-1]) > rand(negative_visible.shape[0], rbm.visible_size)
    
    negative_visible[:, :-1] = sigmoid(negative_hidden @ rbm.W[:-1, :].T) > rand(negative_visible.shape[0], rbm.visible_size) # fantazja
    negative_hidden[:, :-1] = sigmoid(negative_visible @ rbm.W[:, :-1])

    
    # gradient 
    p_g = (positive_visible.T @ positive_hidden) / observations_count
    n_g = (negative_visible.T @ negative_hidden) / observations_count
    g = rbm.learning_rate * p_g - rbm.learning_rate * n_g
    rbm.M[:, :] = rbm.momentum * rbm.M[:, :] - g
    rbm.W = rbm.W - rbm.M

# %%
import time

DATASET_SIZE = 60000 # 60000 for whole dataset
DIGIT_SIZE = 28

VISIBLE_LAYER_SIZE = DIGIT_SIZE*DIGIT_SIZE
HIDDEN_LAYER_SIZE = 128

mnist_train = mnist.train_images().astype(np.float32) / 255.0
np.random.shuffle(mnist_train)
dataset = np.reshape(mnist_train[:DATASET_SIZE], newshape=(DATASET_SIZE, DIGIT_SIZE*DIGIT_SIZE))
dataset = append_ones(dataset)

monitoring_indeces = np.random.choice(DATASET_SIZE, 256, replace=False)
monitoring_set = dataset[monitoring_indeces]

# %%
BATCH_SIZE = 128
EPOCHS_COUNT = 50

LEARNING_RATE = 0.1
MOMENTUM = 0.5

rbm = Rbm(VISIBLE_LAYER_SIZE, HIDDEN_LAYER_SIZE, LEARNING_RATE, MOMENTUM)
draw_filters(rbm)

run_training(rbm, dataset, monitoring_set, BATCH_SIZE, EPOCHS_COUNT)

draw_filters(rbm)
# Out:
# Epoch 0:	#####################################################	elapsed: 1.19s, reconstruction error: 25.79
# Epoch 1:	#####################################################	elapsed: 1.11s, reconstruction error: 21.09
# Epoch 2:	#####################################################	elapsed: 1.19s, reconstruction error: 18.23
# Epoch 3:	#####################################################	elapsed: 1.22s, reconstruction error: 16.76
# Epoch 4:	#####################################################	elapsed: 1.18s, reconstruction error: 16.11
# Epoch 5:	#####################################################	elapsed: 0.91s, reconstruction error: 14.92
# Epoch 6:	#####################################################	elapsed: 1.08s, reconstruction error: 13.82
# Epoch 7:	#####################################################	elapsed: 1.11s, reconstruction error: 13.26
# Epoch 8:	#####################################################	elapsed: 1.01s, reconstruction error: 13.28
# Epoch 9:	#####################################################	elapsed: 1.19s, reconstruction error: 12.63
# Epoch 10:	#####################################################	elapsed: 1.11s, reconstruction error: 11.93
# Epoch 11:	#####################################################	elapsed: 1.00s, reconstruction error: 12.01
# Epoch 12:	#####################################################	elapsed: 0.97s, reconstruction error: 11.25
# Epoch 13:	#####################################################	elapsed: 1.11s, reconstruction error: 11.50
# Epoch 14:	#####################################################	elapsed: 1.19s, reconstruction error: 11.36
# Epoch 15:	#####################################################	elapsed: 1.02s, reconstruction error: 11.20
# Epoch 16:	#####################################################	elapsed: 1.08s, reconstruction error: 11.11
# Epoch 17:	#####################################################	elapsed: 1.22s, reconstruction error: 11.11
# Epoch 18:	#####################################################	elapsed: 1.10s, reconstruction error: 11.15
# Epoch 19:	#####################################################	elapsed: 1.19s, reconstruction error: 10.92
# Epoch 20:	#####################################################	elapsed: 1.08s, reconstruction error: 10.59
# Epoch 21:	#####################################################	elapsed: 1.12s, reconstruction error: 10.59
# Epoch 22:	#####################################################	elapsed: 1.00s, reconstruction error: 10.82
# Epoch 23:	#####################################################	elapsed: 0.99s, reconstruction error: 10.76
# Epoch 24:	#####################################################	elapsed: 1.11s, reconstruction error: 10.70
# Epoch 25:	#####################################################	elapsed: 1.17s, reconstruction error: 10.82
# Epoch 26:	#####################################################	elapsed: 1.20s, reconstruction error: 10.64
# Epoch 27:	#####################################################	elapsed: 0.92s, reconstruction error: 10.27
# Epoch 28:	#####################################################	elapsed: 1.20s, reconstruction error: 10.32
# Epoch 29:	#####################################################	elapsed: 1.10s, reconstruction error: 10.30
# Epoch 30:	#####################################################	elapsed: 1.18s, reconstruction error: 10.37
# Epoch 31:	#####################################################	elapsed: 1.13s, reconstruction error: 9.99
# Epoch 32:	#####################################################	elapsed: 1.11s, reconstruction error: 10.28
# Epoch 33:	#####################################################	elapsed: 1.21s, reconstruction error: 10.06
# Epoch 34:	#####################################################	elapsed: 1.28s, reconstruction error: 10.68
# Epoch 35:	#####################################################	elapsed: 1.12s, reconstruction error: 10.60
# Epoch 36:	#####################################################	elapsed: 1.21s, reconstruction error: 10.27
# Epoch 37:	#####################################################	elapsed: 1.00s, reconstruction error: 10.22
# Epoch 38:	#####################################################	elapsed: 1.17s, reconstruction error: 10.05
# Epoch 39:	#####################################################	elapsed: 1.19s, reconstruction error: 9.90
# Epoch 40:	#####################################################	elapsed: 1.03s, reconstruction error: 10.10
# Epoch 41:	#####################################################	elapsed: 1.10s, reconstruction error: 9.94
# Epoch 42:	#####################################################	elapsed: 1.17s, reconstruction error: 10.39
# Epoch 43:	#####################################################	elapsed: 1.22s, reconstruction error: 10.20
# Epoch 44:	#####################################################	elapsed: 1.17s, reconstruction error: 10.23
# Epoch 45:	#####################################################	elapsed: 1.02s, reconstruction error: 10.11
# Epoch 46:	#####################################################	elapsed: 0.99s, reconstruction error: 10.04
# Epoch 47:	#####################################################	elapsed: 1.01s, reconstruction error: 9.99
# Epoch 48:	#####################################################	elapsed: 1.01s, reconstruction error: 10.23
# Epoch 49:	#####################################################	elapsed: 1.12s, reconstruction error: 10.29
# Training finished!

# %% [markdown]
# # 2. DBN Training

# %%
def propagate_up(dbn, layers_count, visible):
    for i in range(layers_count):
        visible = append_ones(sigmoid(visible @ dbn[i].W[:, :-1]))
    return visible

def propagate_down(dbn, layers_count, hidden):
    for i in reversed(range(layers_count)):
        hidden = append_ones(sigmoid(hidden @ np.transpose(dbn[i].W[:-1, :])))
    return hidden

# %% [markdown]
# ### DBN reconstruction error

# %%
def dbn_reconstuction_error(dbn, layers_count, minibatch):
    v_rbm = propagate_up(dbn, layers_count, minibatch)
    return reconstuction_error(dbn[layers_count], v_rbm)

# %% [markdown]
# ### Sampling in Deep Belief Networks

# %%
def sample_rbm(rbm, minibatch, steps):
    observations_count = minibatch.shape[0]

    visible = minibatch
    hidden = append_ones(zeros(observations_count, rbm.hidden_size))
    
    for cd_i in range(steps):
        hidden[:, :-1] = sigmoid(visible @ rbm.W[:, :-1])
        hidden[:, :-1] = (hidden[:, :-1] > rand(observations_count, rbm.hidden_size)).astype(np.float32)
    
        visible[:, :-1] = sigmoid(hidden @ np.transpose(rbm.W[:-1, :]))
        if cd_i < (steps - 1):
            visible[:, :-1] = (visible[:, :-1] > rand(observations_count, rbm.visible_size)).astype(np.float32)

    return visible

# %%
def sample_dbn(dbn, layer_idx, minibatch, steps):
    # propegte u -> down -> return p(v) 
    visible = minibatch
    top_visible = propagate_up(dbn, layer_idx, visible)
    top_sample = sample_rbm(dbn[layer_idx], top_visible, steps)
    down_sample = propagate_down(dbn, layer_idx, top_sample)
    return down_sample

# %%
def draw_layer_samples(dbn, layer_idx, minibatch, steps=200):
    samples = sample_dbn(dbn, layer_idx, minibatch, steps)
    tiles(np.reshape(samples[:, :-1], newshape=(-1, 16, 28, 28)))

# %% [markdown]
# ### Greedy layer-wise training

# %%
def train_dbn(dbn, layer_idx, dataset, batch_size):
    dataset = propagate_up(dbn ,layer_idx, dataset)

    batches_limit = dataset.shape[0] / batch_size
    for batch_idx, batch in enumerate(chunks(dataset, batch_size)):
        cdk(dbn[layer_idx], batch)
        if batch_idx % round(batches_limit / 50) == 0: print("#", end="")

# %%
BATCH_SIZE = 128
EPOCHS_COUNT = 50

LEARNING_RATE = 0.1
MOMENTUM = 0.5

DBN_HIDDEN_LAYER_SIZE = 200
dbn = [
    Rbm(VISIBLE_LAYER_SIZE, DBN_HIDDEN_LAYER_SIZE, LEARNING_RATE, MOMENTUM),
    Rbm(DBN_HIDDEN_LAYER_SIZE, DBN_HIDDEN_LAYER_SIZE, LEARNING_RATE, MOMENTUM),
    Rbm(DBN_HIDDEN_LAYER_SIZE, DBN_HIDDEN_LAYER_SIZE, LEARNING_RATE, MOMENTUM)
]

for layer_idx in range(len(dbn)):
    print("\nLearning layer {}".format(layer_idx))

    for epoch in range(EPOCHS_COUNT):
        print("Epoch {}:".format(epoch),  end="\t")

        if epoch == 5:
            dbn[layer_idx].momentum = 0.8
        
        start_time = time.time()
        train_dbn(dbn, layer_idx, dataset, BATCH_SIZE)
        elapsed = time.time() - start_time
        
        error = dbn_reconstuction_error(dbn, layer_idx, monitoring_set)
        print("\telapsed: {0:>2.2f}s, reconstruction error: {1:>2.2f}".format(elapsed, error))
    
print("Training finished!")
# Out:
# Learning layer 0
# Epoch 0:	#####################################################	elapsed: 4.13s, reconstruction error: 15.46
# Epoch 1:	#####################################################	elapsed: 4.38s, reconstruction error: 12.74
# Epoch 2:	#####################################################	elapsed: 4.59s, reconstruction error: 11.50
# Epoch 3:	#####################################################	elapsed: 4.72s, reconstruction error: 10.28
# Epoch 4:	#####################################################	elapsed: 4.79s, reconstruction error: 9.76
# Epoch 5:	#####################################################	elapsed: 4.31s, reconstruction error: 9.44
# Epoch 6:	#####################################################	elapsed: 4.68s, reconstruction error: 9.13
# Epoch 7:	#####################################################	elapsed: 4.50s, reconstruction error: 8.82
# Epoch 8:	#####################################################	elapsed: 4.59s, reconstruction error: 8.73
# Epoch 9:	#####################################################	elapsed: 4.51s, reconstruction error: 8.42
# Epoch 10:	#####################################################	elapsed: 4.80s, reconstruction error: 8.79
# Epoch 11:	#####################################################	elapsed: 5.01s, reconstruction error: 8.79
# Epoch 12:	#####################################################	elapsed: 4.90s, reconstruction error: 8.53
# Epoch 13:	#####################################################	elapsed: 4.70s, reconstruction error: 8.82
# Epoch 14:	#####################################################	elapsed: 4.30s, reconstruction error: 8.44
# Epoch 15:	#####################################################	elapsed: 4.56s, reconstruction error: 8.39
# Epoch 16:	#####################################################	elapsed: 5.01s, reconstruction error: 8.15
# Epoch 17:	#####################################################	elapsed: 7.98s, reconstruction error: 8.30
# Epoch 18:	#####################################################	elapsed: 4.62s, reconstruction error: 8.34
# Epoch 19:	#####################################################	elapsed: 4.67s, reconstruction error: 8.59
# Epoch 20:	#####################################################	elapsed: 5.00s, reconstruction error: 8.26
# Epoch 21:	#####################################################	elapsed: 4.73s, reconstruction error: 8.41
# Epoch 22:	#####################################################	elapsed: 4.48s, reconstruction error: 8.46
# Epoch 23:	#####################################################	elapsed: 4.58s, reconstruction error: 8.20
# Epoch 24:	#####################################################	elapsed: 4.71s, reconstruction error: 8.19
# Epoch 25:	#####################################################	elapsed: 4.68s, reconstruction error: 8.36
# Epoch 26:	#############
# /tmp/ipykernel_249726/4013762205.py:2: RuntimeWarning: overflow encountered in exp
#   return 1.0 / (1.0 + np.exp(-matrix))
# ########################################	elapsed: 4.62s, reconstruction error: 8.20
# Epoch 27:	#####################################################	elapsed: 4.97s, reconstruction error: 7.98
# Epoch 28:	#####################################################	elapsed: 4.64s, reconstruction error: 8.14
# Epoch 29:	#####################################################	elapsed: 4.40s, reconstruction error: 8.30
# Epoch 30:	#####################################################	elapsed: 4.61s, reconstruction error: 8.47
# Epoch 31:	#####################################################	elapsed: 4.62s, reconstruction error: 8.10
# Epoch 32:	#####################################################	elapsed: 4.29s, reconstruction error: 7.98
# Epoch 33:	#####################################################	elapsed: 4.49s, reconstruction error: 7.92
# Epoch 34:	#####################################################	elapsed: 4.20s, reconstruction error: 8.23
# Epoch 35:	#####################################################	elapsed: 4.48s, reconstruction error: 8.07
# Epoch 36:	#####################################################	elapsed: 4.42s, reconstruction error: 8.09
# Epoch 37:	#####################################################	elapsed: 4.20s, reconstruction error: 8.01
# Epoch 38:	#####################################################	elapsed: 4.27s, reconstruction error: 7.89
# Epoch 39:	#####################################################	elapsed: 4.29s, reconstruction error: 8.25
# Epoch 40:	#####################################################	elapsed: 4.41s, reconstruction error: 7.94
# Epoch 41:	#####################################################	elapsed: 4.51s, reconstruction error: 7.86
# Epoch 42:	#####################################################	elapsed: 4.20s, reconstruction error: 7.91
# Epoch 43:	#####################################################	elapsed: 4.09s, reconstruction error: 8.14
# Epoch 44:	#####################################################	elapsed: 4.11s, reconstruction error: 7.85
# Epoch 45:	#####################################################	elapsed: 4.29s, reconstruction error: 7.97
# Epoch 46:	#####################################################	elapsed: 4.48s, reconstruction error: 7.70
# Epoch 47:	#####################################################	elapsed: 3.82s, reconstruction error: 7.91
# Epoch 48:	#####################################################	elapsed: 4.41s, reconstruction error: 8.16
# Epoch 49:	#####################################################	elapsed: 3.89s, reconstruction error: 8.32
#
# Learning layer 1
# Epoch 0:	#####################################################	elapsed: 2.08s, reconstruction error: 9.29
# Epoch 1:	#####################################################	elapsed: 1.92s, reconstruction error: 6.75
# Epoch 2:	#####################################################	elapsed: 1.97s, reconstruction error: 5.95
# Epoch 3:	#####################################################	elapsed: 1.80s, reconstruction error: 5.63
# Epoch 4:	#####################################################	elapsed: 2.02s, reconstruction error: 5.02
# Epoch 5:	#####################################################	elapsed: 2.00s, reconstruction error: 4.75
# Epoch 6:	#####################################################	elapsed: 1.92s, reconstruction error: 4.72
# Epoch 7:	#####################################################	elapsed: 1.84s, reconstruction error: 4.73
# Epoch 8:	#####################################################	elapsed: 2.07s, reconstruction error: 4.55
# Epoch 9:	#####################################################	elapsed: 1.93s, reconstruction error: 3.95
# Epoch 10:	#####################################################	elapsed: 1.98s, reconstruction error: 4.24
# Epoch 11:	#####################################################	elapsed: 1.93s, reconstruction error: 4.19
# Epoch 12:	#####################################################	elapsed: 1.74s, reconstruction error: 4.04
# Epoch 13:	#####################################################	elapsed: 1.90s, reconstruction error: 3.82
# Epoch 14:	#####################################################	elapsed: 2.19s, reconstruction error: 4.25
# Epoch 15:	#####################################################	elapsed: 1.81s, reconstruction error: 3.98
# Epoch 16:	#####################################################	elapsed: 2.09s, reconstruction error: 3.80
# Epoch 17:	#####################################################	elapsed: 2.11s, reconstruction error: 4.18
# Epoch 18:	#####################################################	elapsed: 1.88s, reconstruction error: 3.89
# Epoch 19:	#####################################################	elapsed: 2.12s, reconstruction error: 3.83
# Epoch 20:	#####################################################	elapsed: 2.19s, reconstruction error: 3.91
# Epoch 21:	#####################################################	elapsed: 2.08s, reconstruction error: 4.05
# Epoch 22:	#####################################################	elapsed: 2.03s, reconstruction error: 3.77
# Epoch 23:	#####################################################	elapsed: 1.90s, reconstruction error: 3.58
# Epoch 24:	#####################################################	elapsed: 2.07s, reconstruction error: 4.00
# Epoch 25:	#####################################################	elapsed: 2.03s, reconstruction error: 3.85
# Epoch 26:	#####################################################	elapsed: 2.03s, reconstruction error: 4.07
# Epoch 27:	#####################################################	elapsed: 2.08s, reconstruction error: 3.83
# Epoch 28:	#####################################################	elapsed: 2.03s, reconstruction error: 3.88
# Epoch 29:	#####################################################	elapsed: 1.71s, reconstruction error: 3.66
# Epoch 30:	#####################################################	elapsed: 1.72s, reconstruction error: 3.71
# Epoch 31:	#####################################################	elapsed: 2.00s, reconstruction error: 3.82
# Epoch 32:	#####################################################	elapsed: 2.10s, reconstruction error: 3.78
# Epoch 33:	#####################################################	elapsed: 1.93s, reconstruction error: 3.51
# Epoch 34:	#####################################################	elapsed: 2.17s, reconstruction error: 3.75
# Epoch 35:	#####################################################	elapsed: 2.02s, reconstruction error: 3.74
# Epoch 36:	#####################################################	elapsed: 1.91s, reconstruction error: 3.86
# Epoch 37:	#####################################################	elapsed: 2.09s, reconstruction error: 3.55
# Epoch 38:	#####################################################	elapsed: 2.11s, reconstruction error: 3.81
# Epoch 39:	#####################################################	elapsed: 2.26s, reconstruction error: 3.87
# Epoch 40:	#####################################################	elapsed: 1.92s, reconstruction error: 3.58
# Epoch 41:	#####################################################	elapsed: 1.99s, reconstruction error: 3.85
# Epoch 42:	#####################################################	elapsed: 1.90s, reconstruction error: 3.51
# Epoch 43:	#####################################################	elapsed: 1.81s, reconstruction error: 3.45
# Epoch 44:	#####################################################	elapsed: 2.00s, reconstruction error: 3.68
# Epoch 45:	#####################################################	elapsed: 2.10s, reconstruction error: 3.51
# Epoch 46:	#####################################################	elapsed: 2.10s, reconstruction error: 3.56
# Epoch 47:	#####################################################	elapsed: 2.07s, reconstruction error: 3.52
# Epoch 48:	#####################################################	elapsed: 2.02s, reconstruction error: 3.69
# Epoch 49:	#####################################################	elapsed: 2.00s, reconstruction error: 3.85
#
# Learning layer 2
# Epoch 0:	#####################################################	elapsed: 2.11s, reconstruction error: 5.70
# Epoch 1:	#####################################################	elapsed: 2.10s, reconstruction error: 4.93
# Epoch 2:	#####################################################	elapsed: 2.10s, reconstruction error: 4.21
# Epoch 3:	#####################################################	elapsed: 2.36s, reconstruction error: 3.74
# Epoch 4:	#####################################################	elapsed: 2.21s, reconstruction error: 3.57
# Epoch 5:	#####################################################	elapsed: 2.39s, reconstruction error: 3.41
# Epoch 6:	#####################################################	elapsed: 2.01s, reconstruction error: 3.11
# Epoch 7:	#####################################################	elapsed: 2.49s, reconstruction error: 3.24
# Epoch 8:	#####################################################	elapsed: 2.01s, reconstruction error: 2.83
# Epoch 9:	#####################################################	elapsed: 2.21s, reconstruction error: 3.12
# Epoch 10:	#####################################################	elapsed: 2.20s, reconstruction error: 2.93
# Epoch 11:	#####################################################	elapsed: 2.29s, reconstruction error: 2.96
# Epoch 12:	#####################################################	elapsed: 2.21s, reconstruction error: 2.90
# Epoch 13:	#####################################################	elapsed: 2.21s, reconstruction error: 2.91
# Epoch 14:	#####################################################	elapsed: 2.21s, reconstruction error: 2.66
# Epoch 15:	#####################################################	elapsed: 2.23s, reconstruction error: 2.81
# Epoch 16:	#####################################################	elapsed: 2.20s, reconstruction error: 2.74
# Epoch 17:	#####################################################	elapsed: 2.16s, reconstruction error: 2.64
# Epoch 18:	#####################################################	elapsed: 2.04s, reconstruction error: 2.78
# Epoch 19:	#####################################################	elapsed: 2.09s, reconstruction error: 2.90
# Epoch 20:	#####################################################	elapsed: 2.20s, reconstruction error: 2.73
# Epoch 21:	#####################################################	elapsed: 2.07s, reconstruction error: 2.77
# Epoch 22:	#####################################################	elapsed: 2.12s, reconstruction error: 2.79
# Epoch 23:	#####################################################	elapsed: 2.19s, reconstruction error: 2.75
# Epoch 24:	#####################################################	elapsed: 2.21s, reconstruction error: 2.53
# Epoch 25:	#####################################################	elapsed: 2.40s, reconstruction error: 2.74
# Epoch 26:	#####################################################	elapsed: 2.09s, reconstruction error: 2.49
# Epoch 27:	#####################################################	elapsed: 2.37s, reconstruction error: 2.46
# Epoch 28:	#####################################################	elapsed: 2.22s, reconstruction error: 2.48
# Epoch 29:	#####################################################	elapsed: 2.32s, reconstruction error: 2.96
# Epoch 30:	#####################################################	elapsed: 2.09s, reconstruction error: 2.81
# Epoch 31:	#####################################################	elapsed: 2.09s, reconstruction error: 2.62
# Epoch 32:	#####################################################	elapsed: 2.38s, reconstruction error: 2.68
# Epoch 33:	#####################################################	elapsed: 2.32s, reconstruction error: 2.65
# Epoch 34:	#####################################################	elapsed: 2.30s, reconstruction error: 2.87
# Epoch 35:	#####################################################	elapsed: 2.50s, reconstruction error: 2.70
# Epoch 36:	#####################################################	elapsed: 2.10s, reconstruction error: 2.63
# Epoch 37:	#####################################################	elapsed: 2.37s, reconstruction error: 2.77
# Epoch 38:	#####################################################	elapsed: 2.13s, reconstruction error: 2.59
# Epoch 39:	#####################################################	elapsed: 2.39s, reconstruction error: 2.47
# Epoch 40:	#####################################################	elapsed: 2.30s, reconstruction error: 2.57
# Epoch 41:	#####################################################	elapsed: 2.50s, reconstruction error: 2.45
# Epoch 42:	#####################################################	elapsed: 2.30s, reconstruction error: 2.59
# Epoch 43:	#####################################################	elapsed: 2.29s, reconstruction error: 2.65
# Epoch 44:	#####################################################	elapsed: 2.21s, reconstruction error: 2.43
# Epoch 45:	#####################################################	elapsed: 2.30s, reconstruction error: 2.67
# Epoch 46:	#####################################################	elapsed: 2.28s, reconstruction error: 2.63
# Epoch 47:	#####################################################	elapsed: 2.08s, reconstruction error: 2.57
# Epoch 48:	#####################################################	elapsed: 2.22s, reconstruction error: 2.48
# Epoch 49:	#####################################################	elapsed: 2.09s, reconstruction error: 2.45
# Training finished!

# %%
draw_layer_samples(dbn, 0, monitoring_set[:8*16])

# %%
draw_layer_samples(dbn, 1, monitoring_set[:8*16])

# %%
draw_layer_samples(dbn, 2, monitoring_set[:8*16])
